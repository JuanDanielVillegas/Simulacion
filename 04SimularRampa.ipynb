# %%
import numpy as np
import matplotlib.pyplot as mpl

# %%
## Esta funcion simula una rampa
def rampa(ts ,a,k):
    x=[]
    for t in ts:
        x.append(a*(t-k))
    return x

## Función principal del programa
def main(ini, fin, delta):
    ts=np.arange(ini, fin, delta)
    x1=rampa(ts ,1,0)
    x2=rampa(ts ,1,3)
    mpl.plot(ts ,x1)
    mpl.plot(ts ,x2)
    mpl.grid()
    mpl.title('RAMPA NORMAL Y RAMPA CHIDA ')
    mpl.xlabel('Tiempo ')
    mpl.ylabel('Resspuesta ')
    mpl.savefig('ejem3.png',format='png',dpi =300)
    mpl.show()

    print(x2)

# %%
## Este es el punto de entrada al programa
if __name__ =="__main__":
    main (-10 ,10 ,0.1)
# Out:
# [-13.0, -12.9, -12.8, -12.700000000000001, -12.600000000000001, -12.500000000000002, -12.400000000000002, -12.300000000000002, -12.200000000000003, -12.100000000000003, -12.000000000000004, -11.900000000000004, -11.800000000000004, -11.700000000000005, -11.600000000000005, -11.500000000000005, -11.400000000000006, -11.300000000000006, -11.200000000000006, -11.100000000000007, -11.000000000000007, -10.900000000000007, -10.800000000000008, -10.700000000000008, -10.600000000000009, -10.500000000000009, -10.40000000000001, -10.30000000000001, -10.20000000000001, -10.10000000000001, -10.00000000000001, -9.900000000000011, -9.800000000000011, -9.700000000000012, -9.600000000000012, -9.500000000000012, -9.400000000000013, -9.300000000000013, -9.200000000000014, -9.100000000000014, -9.000000000000014, -8.900000000000015, -8.800000000000015, -8.700000000000015, -8.600000000000016, -8.500000000000016, -8.400000000000016, -8.300000000000017, -8.200000000000017, -8.100000000000017, -8.0000000000
# ...
